# %%
"Visualisation d’un nuage de points et exploration des variables"

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv("./data/house_pricing.csv", sep=",")
print("Dataset loaded")
# Out:
# Dataset loaded

# %%
print(dataset.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
dfprice = dataset["SalePrice"]
dfarea = dataset["LotArea"]

sns.scatterplot(dfprice, dfarea)

# %%
df = dataset[(dataset['LotArea'] < 20000) & (df['SalePrice'] < 500000)]
dfprice = df['SalePrice']
dfarea = df['LotArea']

sns.scatterplot(dfprice, dfarea)

# %%
dfprice = dataset["LotFrontage"]
dfarea = dataset["LotArea"]

sns.scatterplot(dfprice, dfarea)

# %%
df = dataset[(dataset['LotFrontage'] < 200) & (df['LotArea'] < 100000)]
dffrontage = df['LotFrontage']
dfarea = df['LotArea']

sns.scatterplot(dffrontage, dfarea)

# %%
"Visualisation de relations continues"

# %%
dataset = pd.read_csv("./data/sales_predictions.csv", sep=",")
print("Dataset loaded")
# Out:
# Dataset loaded

# %%
dataset.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
x = dataset['date']
y = dataset['item_price']

g = sns.relplot(x=x,y=y,data=dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-14eea34fdb8d> in <module>
# ----> 1 x = dataset['date']
# ...

# %%
dataset.sample(n=50)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 405917   16.04.2013               3       58    18225      199.00
# 2530105  11.03.2015              26        3     4872     1199.00
# 1327808  16.01.2014              12       45    16455      699.00
# 308190   14.03.2013               2       28     9910      149.00
# 688776   22.07.2013               6       19    13496    12998.00
# 2055376  04.10.2014              21        5     2814      899.00
# 656582   19.07.2013               6       28    21438      149.00
# 1962396  02.09.2014              20       46    10039      132.67
# 1362109  23.01.2014              12       25     1131      399.00
# 2443069  15.02.2015              25       54    16549      199.00
# 515638   09.05.2013               4       18    12128      429.00
# 1009966  25.10.2013               9        7     1035      299.00
# 2728353  25.07.2015              30       16    16147      599.00
# ...

# %%
e = dataset.sample(n=50)
x = e['date']
y = e['item_price']

g = sns.relplot(x=x,y=y,data=e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-96e4c337e3d6> in <module>
#       1 e = dataset.sample(n=50)
# ...

# %%
e = dataset.sample(n=50)
date = e['date']
pd.to_datetime(date, dayfirst=True)
# Out:
# 1623644   2014-04-14
# 2157066   2014-11-15
# 510310    2013-05-25
# 278104    2013-03-21
# 512       2013-01-31
# 113538    2013-01-04
# 572035    2013-06-21
# 2067780   2014-10-15
# 442432    2013-05-03
# 2405934   2015-01-08
# 2384534   2015-01-03
# 9041      2013-01-14
# 2254918   2014-12-22
# 611037    2013-06-23
# 2749655   2015-07-23
# 1371626   2014-02-23
# 2412887   2015-02-21
# 824812    2013-08-18
# 1566202   2014-04-11
# 221873    2013-02-17
# 894699    2013-09-23
# 58722     2013-01-28
# 2615529   2015-05-19
# 1471140   2014-03-03
# 1772726   2014-06-20
# 561669    2013-06-11
# 2149802   2014-11-14
# 932456    2013-09-11
# 1430387   2014-02-11
# 830284    2013-08-09
# 1577401   2014-04-06
# 2187590   2014-11-19
# 141585    2013-02-23
# 212346    2013-02-14
# 51226     2013-01-22
# 48192     2013-01-05
# 2085613   2014-10-31
# 2792305   2015-08-20
# 857371    2013-09-07
# 2134196   2014-11-07
# 2740803   2015-07-20
# 1073829   2013-11-09
# 1280645   2014-01-21
# ...

# %%
e = dataset.sample(n=50)
date = e['date']
datetime = pd.to_datetime(date, dayfirst=True)
x = datetime
y = e['item_price']

g = sns.relplot(x=x,y=y,data=e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-f53641fa7b2a> in <module>
#       1 e = dataset.sample(n=50)
# ...

# %%
"Visualisation de variables catégoriques"

# %%
dataset = pd.read_csv("./data/IBM_HR_ATTRITION.csv", sep=",")
print("Dataset loaded")
# Out:
# Dataset loaded

# %%
dataset.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
x = dataset['JobSatisfaction']
y = dataset['Attrition']

g = sns.catplot(x = x,y = y, data=dataset)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3f060fdec52d> in <module>
#       2 y = dataset['Attrition']
#       3
# ----> 4 g = sns.catplot(x = x,y = y, data=dataset)
#
# /usr/local/lib/python3.7/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3753
#    3754     # Draw the plot onto the facets
# -> 3755     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3756
# ...

# %%
x = dataset['JobSatisfaction']
y = dataset['Attrition']

g = sns.boxplot(x = x,y = y, data=dataset)

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
x = dataset["JobSatisfaction"]
y = dataset["TotalWorkingYears"]

sns.boxplot(x=x, y=y, data=dataset)

# %%
df = dataset[dataset['Attrition'] == 'Yes']
x = df["EducationField"]
y = df["JobSatisfaction"]

sns.barplot(x=x, y=y, data=df)

# %%
d = dataset["MonthlyIncome"]

sns.distplot(d)

# %%
x = dataset[dataset["MonthlyIncome"] < 5000]

sns.distplot(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-48b7fc247aab> in <module>
#       1 x = dataset[dataset["MonthlyIncome"] < 5000]
#       2
# ----> 3 sns.distplot(x)
#
# /usr/local/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     196             line, = ax.plot(0, a.mean())
#     197         else:
# --> 198             line, = ax.plot(a.mean(), 0)
#     199         color = line.get_color()
#     200         line.remove()
#
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
# ...

# %%
y = dataset["Attrition"].replace('Yes',1).replace('No',0)
x = dataset["DistanceFromHome"]

sns.lmplot(x=x, y=y, data=dataset)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64
# 0        1
# 1        8
# 2        2
# 3        3
# 4        2
#         ..
# 1465    23
# 1466     6
# 1467     4
# 1468     2
# 1469     8
# Name: DistanceFromHome, Length: 1470, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-b3a9d5d92456> in <module>
#       4 print(x)
#       5
# ----> 6 sns.lmplot(x=x, y=y, data=dataset)
#
# ...

# %%
y = dataset["Attrition"].replace('Yes',1).replace('No',0)
x = dataset["YearsWithCurrManager"]

sns.lmplot(x=x, y=y, data=dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-96e7f637f6a7> in <module>
#       2 x = dataset["YearsWithCurrManager"]
#       3
# ----> 4 sns.lmplot(x=x, y=y, data=dataset)
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 551     data = data[cols]
#     552
#     553     # Initialize the grid
#
# ...

# %%
dataset = pd.read_csv("./data/house_pricing.csv", sep=",")
print("Dataset loaded")
# Out:
# Dataset loaded

# %%
df = dataset[0:15]
df.describe
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
u = dataset["LotArea"]
v = dataset["PoolArea"]
w = dataset["SalePrice"]
x = dataset["YearsWithCurrManager"]
y = dataset["YearsWithCurrManager"]
z = dataset["YearsWithCurrManager"]
np.corrcoef(u,v,w,x,y,z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-36ab4ffb7b3e> in <module>
#       1 for x in dataset :
# ----> 2     np.corrcoef(x)
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2524         warnings.warn('bias and ddof have no effect and are deprecated',
#    2525                       DeprecationWarning, stacklevel=3)
# -> 2526     c = cov(x, y, rowvar)
#    2527     try:
#    2528         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2429             w *= aweights
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2432     w_sum = w_sum[0]
# ...
